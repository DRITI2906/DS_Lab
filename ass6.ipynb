# %% [markdown]
# Q1 - Download any dataset with numeric values to plot the histogram as per the values given by the user: I am using Iris datatset here.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('IRIS.csv')

# %%
x_edges = list(map(float, input("Enter x-axis bin edges (comma separated): ").split(",")))
bins = int(input("Enter number of bins: ")) 
bar_color = input("Enter bar color (e.g., blue, green, red): ") 
edge_color = input("Enter edge color (e.g., black, white): ") 
alpha = float(input("Enter transparency value (0-1): "))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x_edges = list(map(float, input("Enter x-axis bin edges (comma separated): ").split(",")))
#       2 bins = int(input("Enter number of bins: "))
#       3 bar_color = input("Enter bar color (e.g., blue, green, red): ")
#
# ValueError: could not convert string to float: 'enter'

# %%
counts, bins_edges, patches = plt.hist(data, bins=x_edges if len(x_edges) > 1 else bins, color=bar_color, edgecolor=edge_color, alpha=alpha)

# %%
plt.xlabel("Sepal Length") plt.ylabel("Frequency") plt.title("Histogram of Iris Sepal Length") plt.show()
